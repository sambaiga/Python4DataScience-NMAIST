# %% [markdown]
# # 1. Pandas library

# %% [markdown]
# To use Panda first load the panda library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 2. Panda Data Structures

# %% [markdown]
# Panda have three fundamental Pdata structures: the **Series**, **DataFrame**, and **Index**.

# %% [markdown]
# ## 2.1 Pandas Series
#
# A pandas Series is a one-dimensional array of indexed data. It can be created from a list or array as follows:

# %% [markdown]
# A series can be constructed with the *pd.Series* constructor (passing a list or array of values) or from a DataFrame, by extracting one of its columns.

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0])
data

# %% [markdown]
# As we see in the output above, the series has both a sequence of **values** and a sequence of **indices**. We can access these with the *values* and *index* attributes.

# %%
data.values

# %%
data.index

# %% [markdown]
# Like with a NumPy array, data can be accessed by the associated index

# %%
data[2]

# %% [markdown]
# ## 2. 2 Pandas DataFrame
#
# A 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL tables.
#
# It is generally the most commonly used pandas object

# %% [markdown]
# ## 2.3 Pandas Index
# An immutable array or as an ordered set which is used to reference and modify data.

# %% [markdown]
# # Exercise 1:
#
# Create a new panda series containing any data.

# %% [markdown]
# # 3. Reading from CSV file into dataframe
#
# You can read data from a CSV file using the **read_csv** function. By default, it assumes that the fields are comma-separated.

# %%
cities = pd.read_csv('Data/Cities.csv')

# %%
# List all the columns in the DataFrame
cities.columns
# Out:
# Index(['city', 'country', 'latitude', 'longitude', 'temperature'], dtype='object')

# %%
# We can use the len function again here to see how many columns there are in the dataframe: 213
len(cities)
# Out:
# 213

# %%
# How big is this dataframe (rows, columns)
cities.shape
# Out:
# (213, 5)

# %%
# Let view the first few rows 
cities.head()
# Out:
#        city         country  latitude  longitude  temperature
# 0   Aalborg         Denmark     57.03       9.92         7.52
# 1  Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2    Abisko          Sweden     63.35      18.83         0.20
# 3     Adana          Turkey     36.99      35.32        18.67
# 4  Albacete           Spain     39.00      -1.87        12.62

# %% [markdown]
# Notice that read_csv automatically considered the first row in the file to be a header row.
# We can override default behavior by customizing some the arguments, like header, names or index_col.

# %%
# View Last 4 rows
cities.tail(4)
# Out:
#           city      country  latitude  longitude  temperature
# 209   Zaragoza        Spain     41.65      -0.89        14.17
# 210   Zhytomyr      Ukraine     50.25      28.66         6.67
# 211  Zonguldak       Turkey     41.43      31.78        10.64
# 212     Zurich  Switzerland     47.38       8.56         6.68

# %% [markdown]
# # Exercise 2:
#
# * Load the Titanic data  as a pandas data frame and inspect the first 5 rows.
# * How many row does the data set contain?

# %%
titanic = pd.read_csv('Data/Titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 3. 2 Adding and Droping column
# Let us add another column to the cities dataframe. Suppose we want to add temperature in Farenheight

# %%
cities['tempF']=cities['temperature']*9/5+32

# %%
cities.head()
# Out:
#        city         country  latitude  longitude  temperature   tempF
# 0   Aalborg         Denmark     57.03       9.92         7.52  45.536
# 1  Aberdeen  United Kingdom     57.17      -2.08         8.10  46.580
# 2    Abisko          Sweden     63.35      18.83         0.20  32.360
# 3     Adana          Turkey     36.99      35.32        18.67  65.606
# 4  Albacete           Spain     39.00      -1.87        12.62  54.716

# %% [markdown]
# It clear from the above result we can perform arthmetic operation on pandas dataframe.

# %% [markdown]
# # <font color="red">Exercise</font>
#
# Add Fare column in Tsh to the titanic dataframe: Hint 1USD = 2000Tsh

# %%
#

# %% [markdown]
# ### Dropping Column
#
# We can  delete column in panda dataframe. Let us delete the tempF column in cities dataframe.

# %%
cities.drop('tempF', axis=1, inplace=True)
cities.head()
# Out:
#        city         country  latitude  longitude  temperature
# 0   Aalborg         Denmark     57.03       9.92         7.52
# 1  Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2    Abisko          Sweden     63.35      18.83         0.20
# 3     Adana          Turkey     36.99      35.32        18.67
# 4  Albacete           Spain     39.00      -1.87        12.62

# %% [markdown]
# ### Note:
#  1. **axis=1** denotes that we are referring to a column, not a row
#  2. **inplace=True** means that the changes are saved to the df right away

# %% [markdown]
# # <font color="red">Exercise</font>
# * Drop the Fare in Tsh you created in the previous exercise.
# * Also delete the ticket and cabin column.
#
# **Hint**: To delete multiple column use *dataframe.drop(['Column_name1', 'Column_name2'], axis=1)*.

# %%
#

# %% [markdown]
# ## 3.3  Slicing Subsets of Rows and Columns in Python

# %% [markdown]
# #### Selecting a single column - returns a 'series'

# %%
cities.city
# Out:
# 0           Aalborg
# 1          Aberdeen
# 2            Abisko
# 3             Adana
# 4          Albacete
# 5         Algeciras
# 6            Amiens
# 7         Amsterdam
# 8            Ancona
# 9           Andorra
# 10           Angers
# 11           Ankara
# 12          Antalya
# 13             Arad
# 14           Athens
# 15         Augsburg
# 16            Bacau
# 17          Badajoz
# 18        Baia Mare
# 19            Balti
# 20        Barcelona
# 21             Bari
# 22            Basel
# 23           Batman
# 24          Belfast
# 25         Belgrade
# 26          Bergamo
# 27           Bergen
# 28           Berlin
# 29        Bialystok
#            ...
# 183           Split
# 184    Stara Zagora
# 185       Stavanger
# 186       Stockholm
# 187            Sumy
# 188         Swansea
# 189          Szeged
# 190         Tallinn
# 191         Tampere
# 192          Tarsus
# 193           Tartu
# 194        Tekirdag
# 195        Toulouse
# 196         Trabzon
# 197         Trieste
# 198         Trikala
# 199       Trondheim
# 200           Turku
# 201         Uppsala
# 202        Valencia
# 203          Vienna
# 204            Vigo
# 205         Vilnius
# 206          Warsaw
# 207         Wroclaw
# 208     Yevpatoriya
# 209        Zaragoza
# 210        Zhytomyr
# 211       Zonguldak
# 212          Zurich
# Name: city, dtype: object

# %%
# Also show try
cities[['temperature']]
# Out:
#      temperature
# 0           7.52
# 1           8.10
# 2           0.20
# 3          18.67
# 4          12.62
# 5          17.38
# 6          10.17
# 7           8.93
# 8          13.52
# 9           9.60
# 10         10.98
# 11          9.86
# 12         11.88
# 13          9.32
# 14         17.41
# 15          4.54
# 16          7.51
# 17         15.61
# 18          8.87
# 19          8.23
# 20         15.78
# 21         15.15
# 22          6.68
# 23         14.16
# 24          8.48
# 25          9.85
# 26          9.12
# 27          1.75
# 28          8.72
# 29          6.07
# ..           ...
# 183        12.46
# 184        10.90
# 185         5.53
# 186         6.26
# 187         6.28
# 188         9.73
# 189        10.34
# 190         4.82
# 191         3.59
# 192        11.21
# 193         4.36
# 194        13.02
# 195        10.25
# 196        10.28
# 197        11.21
# 198        16.00
# 199         4.53
# 200         4.72
# 201         4.17
# 202        16.02
# 203         7.86
# 204        12.85
# 205         5.38
# 206         7.20
# 207         7.17
# 208        10.02
# 209        14.17
# 210         6.67
# 211        10.64
# 212         6.68
#
# [213 rows x 1 columns]

# %% [markdown]
# #### Selecting multiple columns - returns a dataframe

# %%
cities[['city','temperature']]
# Out:
#              city  temperature
# 0         Aalborg         7.52
# 1        Aberdeen         8.10
# 2          Abisko         0.20
# 3           Adana        18.67
# 4        Albacete        12.62
# 5       Algeciras        17.38
# 6          Amiens        10.17
# 7       Amsterdam         8.93
# 8          Ancona        13.52
# 9         Andorra         9.60
# 10         Angers        10.98
# 11         Ankara         9.86
# 12        Antalya        11.88
# 13           Arad         9.32
# 14         Athens        17.41
# 15       Augsburg         4.54
# 16          Bacau         7.51
# 17        Badajoz        15.61
# 18      Baia Mare         8.87
# 19          Balti         8.23
# 20      Barcelona        15.78
# 21           Bari        15.15
# 22          Basel         6.68
# 23         Batman        14.16
# 24        Belfast         8.48
# 25       Belgrade         9.85
# 26        Bergamo         9.12
# 27         Bergen         1.75
# 28         Berlin         8.72
# 29      Bialystok         6.07
# ..            ...          ...
# 183         Split        12.46
# 184  Stara Zagora        10.90
# 185     Stavanger         5.53
# 186     Stockholm         6.26
# 187          Sumy         6.28
# 188       Swansea         9.73
# 189        Szeged        10.34
# 190       Tallinn         4.82
# 191       Tampere         3.59
# 192        Tarsus        11.21
# 193         Tartu         4.36
# 194      Tekirdag        13.02
# 195      Toulouse        10.25
# 196       Trabzon        10.28
# 197       Trieste        11.21
# 198       Trikala        16.00
# 199     Trondheim         4.53
# 200         Turku         4.72
# 201       Uppsala         4.17
# 202      Valencia        16.02
# 203        Vienna         7.86
# 204          Vigo        12.85
# 205       Vilnius         5.38
# 206        Warsaw         7.20
# 207       Wroclaw         7.17
# 208   Yevpatoriya        10.02
# 209      Zaragoza        14.17
# 210      Zhytomyr         6.67
# 211     Zonguldak        10.64
# 212        Zurich         6.68
#
# [213 rows x 2 columns]

# %% [markdown]
# #### Selecting rows by number

# %%
cities[15:20]
# Out:
#          city  country  latitude  longitude  temperature
# 15   Augsburg  Germany     48.35      10.90         4.54
# 16      Bacau  Romania     46.58      26.92         7.51
# 17    Badajoz    Spain     38.88      -6.97        15.61
# 18  Baia Mare  Romania     47.66      23.58         8.87
# 19      Balti  Moldova     47.76      27.91         8.23

# %%
# Try  cities[:8] and cities[200:]
cities[:8]
# Out:
#         city         country  latitude  longitude  temperature
# 0    Aalborg         Denmark     57.03       9.92         7.52
# 1   Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2     Abisko          Sweden     63.35      18.83         0.20
# 3      Adana          Turkey     36.99      35.32        18.67
# 4   Albacete           Spain     39.00      -1.87        12.62
# 5  Algeciras           Spain     36.13      -5.47        17.38
# 6     Amiens          France     49.90       2.30        10.17
# 7  Amsterdam     Netherlands     52.35       4.92         8.93

# %% [markdown]
# ## 3.4 Position Based Selection of columns and lows
# Pandas allows us to use position based indexing implemented with iloc and loc:
# >**.loc** for label-based indexing
#
# >**.iloc** for positional indexing

# %% [markdown]
# #### To slice a specific column using label indexing

# %%
# And here is how to slice a column:
cities.loc[: , "temperature"]
# Out:
# 0       7.52
# 1       8.10
# 2       0.20
# 3      18.67
# 4      12.62
# 5      17.38
# 6      10.17
# 7       8.93
# 8      13.52
# 9       9.60
# 10     10.98
# 11      9.86
# 12     11.88
# 13      9.32
# 14     17.41
# 15      4.54
# 16      7.51
# 17     15.61
# 18      8.87
# 19      8.23
# 20     15.78
# 21     15.15
# 22      6.68
# 23     14.16
# 24      8.48
# 25      9.85
# 26      9.12
# 27      1.75
# 28      8.72
# 29      6.07
#        ...
# 183    12.46
# 184    10.90
# 185     5.53
# 186     6.26
# 187     6.28
# 188     9.73
# 189    10.34
# 190     4.82
# 191     3.59
# 192    11.21
# 193     4.36
# 194    13.02
# 195    10.25
# 196    10.28
# 197    11.21
# 198    16.00
# 199     4.53
# 200     4.72
# 201     4.17
# 202    16.02
# 203     7.86
# 204    12.85
# 205     5.38
# 206     7.20
# 207     7.17
# 208    10.02
# 209    14.17
# 210     6.67
# 211    10.64
# 212     6.68
# Name: temperature, dtype: float64

# %% [markdown]
# We can also use postion indexing

# %%
cities.iloc[:,4]
# Out:
# 0       7.52
# 1       8.10
# 2       0.20
# 3      18.67
# 4      12.62
# 5      17.38
# 6      10.17
# 7       8.93
# 8      13.52
# 9       9.60
# 10     10.98
# 11      9.86
# 12     11.88
# 13      9.32
# 14     17.41
# 15      4.54
# 16      7.51
# 17     15.61
# 18      8.87
# 19      8.23
# 20     15.78
# 21     15.15
# 22      6.68
# 23     14.16
# 24      8.48
# 25      9.85
# 26      9.12
# 27      1.75
# 28      8.72
# 29      6.07
#        ...
# 183    12.46
# 184    10.90
# 185     5.53
# 186     6.26
# 187     6.28
# 188     9.73
# 189    10.34
# 190     4.82
# 191     3.59
# 192    11.21
# 193     4.36
# 194    13.02
# 195    10.25
# 196    10.28
# 197    11.21
# 198    16.00
# 199     4.53
# 200     4.72
# 201     4.17
# 202    16.02
# 203     7.86
# 204    12.85
# 205     5.38
# 206     7.20
# 207     7.17
# 208    10.02
# 209    14.17
# 210     6.67
# 211    10.64
# 212     6.68
# Name: temperature, dtype: float64

# %% [markdown]
# ####  To extract only a row you would do the inverse:

# %%
cities.iloc[4,:]
# Out:
# city           Albacete
# country           Spain
# latitude             39
# longitude         -1.87
# temperature       12.62
# Name: 4, dtype: object

# %% [markdown]
# #### To select range of row and column

# %%
## Select first four rows(including header) and first three column (including SN)
cities.iloc[0:3,0:2]
# Out:
#        city         country
# 0   Aalborg         Denmark
# 1  Aberdeen  United Kingdom
# 2    Abisko          Sweden

# %% [markdown]
# #### Select only the specified range of column

# %%
cities.iloc[:,0:2] #
# Out:
#              city         country
# 0         Aalborg         Denmark
# 1        Aberdeen  United Kingdom
# 2          Abisko          Sweden
# 3           Adana          Turkey
# 4        Albacete           Spain
# 5       Algeciras           Spain
# 6          Amiens          France
# 7       Amsterdam     Netherlands
# 8          Ancona           Italy
# 9         Andorra         Andorra
# 10         Angers          France
# 11         Ankara          Turkey
# 12        Antalya          Turkey
# 13           Arad         Romania
# 14         Athens          Greece
# 15       Augsburg         Germany
# 16          Bacau         Romania
# 17        Badajoz           Spain
# 18      Baia Mare         Romania
# 19          Balti         Moldova
# 20      Barcelona           Spain
# 21           Bari           Italy
# 22          Basel     Switzerland
# 23         Batman          Turkey
# 24        Belfast  United Kingdom
# 25       Belgrade          Serbia
# 26        Bergamo           Italy
# 27         Bergen          Norway
# 28         Berlin         Germany
# 29      Bialystok          Poland
# ..            ...             ...
# 183         Split         Croatia
# 184  Stara Zagora        Bulgaria
# 185     Stavanger          Norway
# 186     Stockholm          Sweden
# 187          Sumy         Ukraine
# 188       Swansea  United Kingdom
# 189        Szeged         Hungary
# 190       Tallinn         Estonia
# 191       Tampere         Finland
# 192        Tarsus          Turkey
# 193         Tartu         Estonia
# 194      Tekirdag          Turkey
# 195      Toulouse          France
# 196       Trabzon          Turkey
# 197       Trieste           Italy
# 198       Trikala          Greece
# 199     Trondheim          Norway
# 200         Turku         Finland
# 201       Uppsala          Sweden
# 202      Valencia           Spain
# 203        Vienna         Austria
# 204          Vigo           Spain
# 205       Vilnius       Lithuania
# 206        Warsaw          Poland
# 207       Wroclaw          Poland
# 208   Yevpatoriya         Ukraine
# 209      Zaragoza           Spain
# 210      Zhytomyr         Ukraine
# 211     Zonguldak          Turkey
# 212        Zurich     Switzerland
#
# [213 rows x 2 columns]

# %% [markdown]
# #### To select  different columns

# %%
cities.iloc[:,[1, 4]]
# Out:
#             country  temperature
# 0           Denmark         7.52
# 1    United Kingdom         8.10
# 2            Sweden         0.20
# 3            Turkey        18.67
# 4             Spain        12.62
# 5             Spain        17.38
# 6            France        10.17
# 7       Netherlands         8.93
# 8             Italy        13.52
# 9           Andorra         9.60
# 10           France        10.98
# 11           Turkey         9.86
# 12           Turkey        11.88
# 13          Romania         9.32
# 14           Greece        17.41
# 15          Germany         4.54
# 16          Romania         7.51
# 17            Spain        15.61
# 18          Romania         8.87
# 19          Moldova         8.23
# 20            Spain        15.78
# 21            Italy        15.15
# 22      Switzerland         6.68
# 23           Turkey        14.16
# 24   United Kingdom         8.48
# 25           Serbia         9.85
# 26            Italy         9.12
# 27           Norway         1.75
# 28          Germany         8.72
# 29           Poland         6.07
# ..              ...          ...
# 183         Croatia        12.46
# 184        Bulgaria        10.90
# 185          Norway         5.53
# 186          Sweden         6.26
# 187         Ukraine         6.28
# 188  United Kingdom         9.73
# 189         Hungary        10.34
# 190         Estonia         4.82
# 191         Finland         3.59
# 192          Turkey        11.21
# 193         Estonia         4.36
# 194          Turkey        13.02
# 195          France        10.25
# 196          Turkey        10.28
# 197           Italy        11.21
# 198          Greece        16.00
# 199          Norway         4.53
# 200         Finland         4.72
# 201          Sweden         4.17
# 202           Spain        16.02
# 203         Austria         7.86
# 204           Spain        12.85
# 205       Lithuania         5.38
# 206          Poland         7.20
# 207          Poland         7.17
# 208         Ukraine        10.02
# 209           Spain        14.17
# 210         Ukraine         6.67
# 211          Turkey        10.64
# 212     Switzerland         6.68
#
# [213 rows x 2 columns]

# %% [markdown]
# # <font color="red">Exercise</font>
#
# * What happens when you type the code below?
# > ```python
#      cities.loc[[0, 10, 200], :]
#   ```
#
# * What happens when you type
# > ```python
#     cities.iloc[0:4, 1:4]
#     cities.loc[0:4, 1:4]
#   ```
#  How are the two commands different?
#
#
# * What happens when you type:
# >
# ```python
#           cities[0:3]
#           cities[:5]
#           cities[-1:]
# ```

# %% [markdown]
# ## 3.5 Subsetting Data Using Criteria
# We can also select a subset of our data using criteria. For example, we can select all rows that have temprature higher than 15.

# %%
cities[cities.temperature > 15]
# Out:
#           city   country  latitude  longitude  temperature
# 3        Adana    Turkey     36.99      35.32        18.67
# 5    Algeciras     Spain     36.13      -5.47        17.38
# 14      Athens    Greece     37.98      23.73        17.41
# 17     Badajoz     Spain     38.88      -6.97        15.61
# 20   Barcelona     Spain     41.38       2.18        15.78
# 21        Bari     Italy     41.11      16.87        15.15
# 59   Cartagena     Spain     37.60      -0.98        17.32
# 60     Catania     Italy     37.50      15.08        15.04
# 68     Cosenza     Italy     39.27      16.29        16.60
# 72     Denizli    Turkey     37.77      29.08        15.02
# 78     Elbasan   Albania     41.12      20.08        15.18
# 94     Granada     Spain     37.16      -3.59        16.33
# 103     Huelva     Spain     37.25      -6.93        17.09
# 108   Kalamata    Greece     37.04      22.11        17.30
# 126     Lisbon  Portugal     38.72      -9.14        15.52
# 135     Manisa    Turkey     38.63      27.44        15.10
# 136   Marbella     Spain     36.52      -4.88        17.19
# 139    Messina     Italy     38.20      15.55        16.54
# 156    Palermo     Italy     38.13      13.35        17.90
# 157     Patras    Greece     38.23      21.73        16.90
# 160    Pescara     Italy     42.46      14.22        15.13
# 171       Rome     Italy     41.90      12.48        15.10
# 198    Trikala    Greece     39.56      21.77        16.00
# 202   Valencia     Spain     39.49      -0.40        16.02

# %% [markdown]
# Or we can select all rows which are in France

# %%
cities[cities.country == 'France']
# Out:
#             city country  latitude  longitude  temperature
# 6         Amiens  France     49.90       2.30        10.17
# 10        Angers  France     47.48      -0.53        10.98
# 38      Bordeaux  France     44.85      -0.60        11.87
# 46         Brest  France     48.39      -4.50        11.02
# 57          Caen  France     49.18      -0.35         9.96
# 73         Dijon  France     47.33       5.03         8.69
# 96      Grenoble  France     45.18       5.72         8.40
# 122      Le Mans  France     48.00       0.10        10.59
# 123        Lille  France     50.65       3.08         9.65
# 124      Limoges  France     45.83       1.25        10.32
# 137    Marseille  France     43.29       5.38        14.98
# 140         Metz  France     49.12       6.18         8.88
# 143  Montpellier  France     43.61       3.87        11.11
# 144     Mulhouse  France     47.75       7.35         6.68
# 146         Nice  France     43.72       7.27         8.82
# 158    Perpignan  France     42.70       2.90        10.95
# 167        Reims  France     49.25       4.03         9.40
# 195     Toulouse  France     43.62       1.45        10.25

# %% [markdown]
# We can also use string operations. For exampme select rows with countries with **"ia"** in their name.

# %%
cities[cities.country.str.contains('ia')]

# %% [markdown]
# ## 3.6  Sort Data in Pandas
#
# We can also sort data in pandas. For example let us  sort the dataframe's rows by latitude, in descending order.

# %%
cities.sort_values(by='latitude', ascending=0)
# Out:
#            city         country  latitude  longitude  temperature
# 116      Kiruna          Sweden     67.85      20.22        -2.20
# 35         Bodo          Norway     67.25      14.40         4.50
# 154        Oulu         Finland     65.00      25.47         1.45
# 199   Trondheim          Norway     63.42      10.42         4.53
# 2        Abisko          Sweden     63.35      18.83         0.20
# 191     Tampere         Finland     61.50      23.75         3.59
# 200       Turku         Finland     60.45      22.25         4.72
# 27       Bergen          Norway     60.39       5.32         1.75
# 100    Helsinki         Finland     60.18      24.93         4.19
# 152        Oslo          Norway     59.92      10.75         2.32
# 201     Uppsala          Sweden     59.86      17.64         4.17
# 190     Tallinn         Estonia     59.43      24.73         4.82
# 186   Stockholm          Sweden     59.35      18.10         6.26
# 185   Stavanger          Norway     58.97       5.68         5.53
# 193       Tartu         Estonia     58.38      26.71         4.36
# 93     Göteborg          Sweden     57.75      12.00         5.76
# 106   Inverness  United Kingdom     57.47      -4.23         8.00
# 1      Aberdeen  United Kingdom     57.17      -2.08         8.10
# 0       Aalborg         Denmark     57.03       9.92         7.52
# 168        Riga          Latvia     56.95      24.10         5.16
# 75       Dundee  United Kingdom     56.47      -3.00         6.40
# 76    Edinburgh  United Kingdom     55.95      -3.22         7.43
# 70   Daugavpils          Latvia     55.88      26.51         5.38
# 92      Glasgow  United Kingdom     55.87      -4.25         8.60
# 117    Klaipeda       Lithuania     55.72      21.12         7.00
# 134       Malmö          Sweden     55.58      13.03         7.33
# 149      Odense         Denmark     55.40      10.38         7.73
# 111      Kaunas       Lithuania     54.95      23.88         6.05
# 205     Vilnius       Lithuania     54.68      25.32         5.38
# 24      Belfast  United Kingdom     54.60      -5.96         8.48
# ..          ...             ...       ...        ...          ...
# 81     Erzincan          Turkey     39.75      39.49         8.67
# 198     Trikala          Greece     39.56      21.77        16.00
# 202    Valencia           Spain     39.49      -0.40        16.02
# 68      Cosenza           Italy     39.27      16.29        16.60
# 4      Albacete           Spain     39.00      -1.87        12.62
# 17      Badajoz           Spain     38.88      -6.97        15.61
# 112     Kayseri          Turkey     38.73      35.49         8.89
# 126      Lisbon        Portugal     38.72      -9.14        15.52
# 135      Manisa          Turkey     38.63      27.44        15.10
# 133     Malatya          Turkey     38.37      38.30        14.13
# 157      Patras          Greece     38.23      21.73        16.90
# 139     Messina           Italy     38.20      15.55        16.54
# 156     Palermo           Italy     38.13      13.35        17.90
# 14       Athens          Greece     37.98      23.73        17.41
# 145      Murcia           Spain     37.98      -1.13        15.00
# 180       Siirt          Turkey     37.94      41.93        12.48
# 23       Batman          Turkey     37.89      41.14        14.16
# 72      Denizli          Turkey     37.77      29.08        15.02
# 59    Cartagena           Spain     37.60      -0.98        17.32
# 60      Catania           Italy     37.50      15.08        15.04
# 103      Huelva           Spain     37.25      -6.93        17.09
# 109     Karaman          Turkey     37.18      33.22        10.41
# 94      Granada           Spain     37.16      -3.59        16.33
# 89    Gaziantep          Turkey     37.07      37.38        13.46
# 108    Kalamata          Greece     37.04      22.11        17.30
# 3         Adana          Turkey     36.99      35.32        18.67
# 192      Tarsus          Turkey     36.92      34.88        11.21
# 12      Antalya          Turkey     36.89      30.70        11.88
# 136    Marbella           Spain     36.52      -4.88        17.19
# 5     Algeciras           Spain     36.13      -5.47        17.38
#
# [213 rows x 5 columns]

# %% [markdown]
# Sorting by country and then by  temperature descending

# %%
cities.sort_values(by=['country','temperature'],ascending=[True,False])
# Out:
#              city                 country  latitude  longitude  temperature
# 78        Elbasan                 Albania     41.12      20.08        15.18
# 9         Andorra                 Andorra     42.50       1.52         9.60
# 203        Vienna                 Austria     48.20      16.37         7.86
# 95           Graz                 Austria     47.08      15.41         6.91
# 125          Linz                 Austria     48.32      14.29         6.79
# 175      Salzburg                 Austria     47.81      13.04         4.62
# 105     Innsbruck                 Austria     47.28      11.41         4.54
# 47          Brest                 Belarus     52.10      23.70         6.73
# 161         Pinsk                 Belarus     52.13      26.09         6.42
# 138         Mazyr                 Belarus     52.05      29.27         6.25
# 102        Hrodna                 Belarus     53.68      23.83         6.07
# 142         Minsk                 Belarus     53.90      27.57         5.28
# 151         Orsha                 Belarus     54.52      30.42         4.93
# 49         Brugge                 Belgium     51.22       3.23         9.65
# 178      Sarajevo  Bosnia and Herzegovina     43.85      13.38         9.60
# 52         Burgas                Bulgaria     42.51      27.47        11.93
# 184  Stara Zagora                Bulgaria     42.42      25.62        10.90
# 173          Ruse                Bulgaria     43.85      25.97        10.59
# 162        Pleven                Bulgaria     43.42      24.61        10.51
# 163       Plovdiv                Bulgaria     42.15      24.75         8.27
# 183         Split                 Croatia     43.52      16.47        12.46
# 169        Rijeka                 Croatia     45.33      14.45         9.27
# 166        Prague          Czech Republic     50.08      14.47         8.05
# 48           Brno          Czech Republic     49.20      16.61         7.86
# 153       Ostrava          Czech Republic     49.83      18.25         7.66
# 149        Odense                 Denmark     55.40      10.38         7.73
# 0         Aalborg                 Denmark     57.03       9.92         7.52
# 190       Tallinn                 Estonia     59.43      24.73         4.82
# 193         Tartu                 Estonia     58.38      26.71         4.36
# 200         Turku                 Finland     60.45      22.25         4.72
# ..            ...                     ...       ...        ...          ...
# 181         Sivas                  Turkey     39.75      37.03         8.05
# 82        Erzurum                  Turkey     39.92      41.29         5.17
# 208   Yevpatoriya                 Ukraine     45.20      33.36        10.02
# 132     Makiyivka                 Ukraine     48.03      37.97         8.70
# 113       Kherson                 Ukraine     46.63      32.60         8.64
# 121    Kryvyy Rih                 Ukraine     47.93      33.34         8.61
# 120    Kremenchuk                 Ukraine     49.08      33.43         7.43
# 62       Cherkasy                 Ukraine     49.43      32.07         7.19
# 101      Horlivka                 Ukraine     48.30      38.05         7.12
# 64     Chernivtsi                 Ukraine     48.31      25.92         7.06
# 128          Lvov                 Ukraine     49.83      24.03         7.04
# 31   Bila Tserkva                 Ukraine     49.77      30.13         6.98
# 115          Kiev                 Ukraine     50.43      30.52         6.88
# 170         Rivne                 Ukraine     50.62      26.25         6.76
# 210      Zhytomyr                 Ukraine     50.25      28.66         6.67
# 187          Sumy                 Ukraine     50.92      34.78         6.28
# 63      Chernihiv                 Ukraine     51.50      31.30         5.92
# 84         Exeter          United Kingdom     50.70      -3.53        10.14
# 40    Bournemouth          United Kingdom     50.73      -1.90         9.97
# 188       Swansea          United Kingdom     51.63      -3.95         9.73
# 58      Cambridge          United Kingdom     52.20       0.12         9.25
# 34      Blackpool          United Kingdom     53.83      -3.05         9.15
# 33     Birmingham          United Kingdom     52.47      -1.92         8.81
# 92        Glasgow          United Kingdom     55.87      -4.25         8.60
# 24        Belfast          United Kingdom     54.60      -5.96         8.48
# 41       Bradford          United Kingdom     53.80      -1.75         8.39
# 1        Aberdeen          United Kingdom     57.17      -2.08         8.10
# 106     Inverness          United Kingdom     57.47      -4.23         8.00
# 76      Edinburgh          United Kingdom     55.95      -3.22         7.43
# 75         Dundee          United Kingdom     56.47      -3.00         6.40
#
# [213 rows x 5 columns]

# %% [markdown]
#  **Putting it together**: Select City and longitude of all cities with latitude > 50 and temperature > 9, sorted by longitude

# %%
temp1 = cities[(cities.latitude > 50) & (cities.temperature > 9)]
temp2 = temp1[['city','longitude']]
temp2.sort_values(by='longitude')
# Show combining first two, then combining all (use \ for long lines)
# Note similar functionality to SQL
# Out:
#             city  longitude
# 88        Galway      -9.05
# 67          Cork      -8.50
# 188      Swansea      -3.95
# 84        Exeter      -3.53
# 34     Blackpool      -3.05
# 40   Bournemouth      -1.90
# 58     Cambridge       0.12
# 123        Lille       3.08
# 49        Brugge       3.23

# %% [markdown]
# The above code is equivalent to:

# %%
cities[(cities.latitude > 50) & (cities.temperature > 9)][['city','longitude']].sort_values(by='longitude')
# Out:
#             city  longitude
# 88        Galway      -9.05
# 67          Cork      -8.50
# 188      Swansea      -3.95
# 84        Exeter      -3.53
# 34     Blackpool      -3.05
# 40   Bournemouth      -1.90
# 58     Cambridge       0.12
# 123        Lille       3.08
# 49        Brugge       3.23

# %% [markdown]
# # <font color="red">Exercise</font>
#
# * Select all teenagers female passengers in titanic dataset.
# * Use the titanic data to print the name, age and gender of all survived passengers less than 20 years old in class C sorted by their age (smallest to lagest).

# %% [markdown]
# ## 4. Descriptive Statistics  From Data
#
# Descriptive statistics can give you great insight into the shape of each attribute. The **describe()** function on the Pandas DataFrame lists 8 statistical properties of each attribute:
#
# * Count
# * Mean
# * Standard Devaition
# * Minimum Value
# * 25th Percentile
# * 50th Percentile (Median)
# * 75th Percentile
# * Maximum Value
#
# For example to obtain the statistics summary  for Cities data.

# %%
cities.describe()
# Out:
#          latitude   longitude  temperature
# count  213.000000  213.000000   213.000000
# mean    47.499906   15.374319     9.497840
# std      6.730961   13.068014     3.561231
# min     36.130000   -9.140000    -2.200000
# 25%     42.220000    5.380000     7.190000
# 50%     47.580000   16.180000     8.880000
# 75%     52.050000   25.620000    11.190000
# max     67.850000   41.930000    18.670000

# %% [markdown]
# To obtain descriptive statistics of a particular column use:

# %%
cities['temperature'].mean()
# Out:
# 9.497840375586858

# %% [markdown]
# ### Groupby
# However we often want to calculate summary statistics grouped by subsets or attributes within fields of our data. For example, we might want to calculate the average tempearture of all cities per countries. To accomplish this we  can use  **.groupby** method

# %%
cities.groupby('country').describe()
# Out:
#                        latitude  longitude  temperature
# country
# Albania        count   1.000000   1.000000     1.000000
#                mean   41.120000  20.080000    15.180000
#                std          NaN        NaN          NaN
#                min    41.120000  20.080000    15.180000
#                25%    41.120000  20.080000    15.180000
#                50%    41.120000  20.080000    15.180000
#                75%    41.120000  20.080000    15.180000
#                max    41.120000  20.080000    15.180000
# Andorra        count   1.000000   1.000000     1.000000
#                mean   42.500000   1.520000     9.600000
#                std          NaN        NaN          NaN
#                min    42.500000   1.520000     9.600000
#                25%    42.500000   1.520000     9.600000
#                50%    42.500000   1.520000     9.600000
#                75%    42.500000   1.520000     9.600000
#                max    42.500000   1.520000     9.600000
# Austria        count   5.000000   5.000000     5.000000
#                mean   47.738000  14.104000     6.144000
#                std     0.547741   1.953505     1.486953
#                min    47.080000  11.410000     4.540000
#                25%    47.280000  13.040000     4.620000
#                50%    47.810000  14.290000     6.790000
#                75%    48.200000  15.410000     6.910000
#                max    48.320000  16.370000     7.860000
# Belarus        count   6.000000   6.000000     6.000000
#                mean   53.063333  26.813333     5.946667
#                std     1.098010   2.783240     0.696123
#                min    52.050000  23.700000     4.930000
#                25%    52.107500  24.395000     5.477500
#                50%    52.905000  26.830000     6.160000
# ...                         ...        ...          ...
# Switzerland    std     0.740023   1.217908     0.993042
#                min    46.210000   6.140000     6.680000
#                25%    46.795000   6.865000     6.680000
#                50%    47.380000   7.590000     6.680000
#                75%    47.480000   8.075000     7.540000
#                max    47.580000   8.560000     8.400000
# Turkey         count  24.000000  24.000000    24.000000
#                mean   39.257083  34.331250    11.726667
#                std     1.644068   4.823203     2.748552
#                min    36.890000  26.570000     5.170000
#                25%    37.860000  30.167500    10.377500
#                50%    39.750000  35.100000    11.545000
#                75%    40.982500  37.977500    13.265000
#                max    41.670000  41.930000    18.670000
# Ukraine        count  15.000000  15.000000    15.000000
#                mean   49.082000  31.494000     7.420000
#                std     1.703971   4.080169     1.093905
#                min    45.200000  24.030000     5.920000
#                25%    48.165000  29.395000     6.820000
#                50%    49.430000  32.070000     7.060000
#                75%    50.340000  33.395000     8.020000
#                max    51.500000  38.050000    10.020000
# United Kingdom count  13.000000  13.000000    13.000000
#                mean   54.068462  -2.978462     8.650000
#                std     2.391631   1.516162     1.046399
#                min    50.700000  -5.960000     6.400000
#                25%    52.200000  -3.950000     8.100000
#                50%    53.830000  -3.050000     8.600000
#                75%    55.950000  -1.920000     9.250000
#                max    57.470000   0.120000    10.140000
#
# [296 rows x 3 columns]

# %% [markdown]
# Let find average temperature of cities in each country

# %%
cities.groupby('country')[['temperature']].mean()
# Out:
#                         temperature
# country
# Albania                   15.180000
# Andorra                    9.600000
# Austria                    6.144000
# Belarus                    5.946667
# Belgium                    9.650000
# Bosnia and Herzegovina     9.600000
# Bulgaria                  10.440000
# Croatia                   10.865000
# Czech Republic             7.856667
# Denmark                    7.625000
# Estonia                    4.590000
# Finland                    3.487500
# France                    10.151111
# Germany                    7.869286
# Greece                    16.902500
# Hungary                    9.602500
# Ireland                    9.300000
# Italy                     13.474667
# Latvia                     5.270000
# Lithuania                  6.143333
# Macedonia                  9.360000
# Moldova                    8.415000
# Montenegro                 9.990000
# Netherlands                8.756667
# Norway                     3.726000
# Poland                     7.250000
# Portugal                  14.470000
# Romania                    9.224444
# Serbia                     9.850000
# Slovakia                   8.480000
# Slovenia                   9.270000
# Spain                     14.238333
# Sweden                     3.586667
# Switzerland                7.253333
# Turkey                    11.726667
# Ukraine                    7.420000
# United Kingdom             8.650000

# %%
# Average temperature of cities in France.
french = cities[cities.country == 'France']
french['temperature'].mean()

# %% [markdown]
# ### Writing Out Data to CSV
#
# We can use the **to_csv** command to do export a DataFrame in CSV format. We can save it to a different folder by adding the foldername and a slash to the file **.to_csv('foldername/filename.csv')**.

# %%
#Save the citiesext to harddisk
cities.to_csv('Data/cities_nmst.csv')

# %% [markdown]
# # 6 Plotting and Visualization
#
# There are a handful of third-party Python packages that are suitable for creating scientific plots and visualizations. These include packages like:
#
# 1. [Matplotlib](http://matplotlib.org/)
# 2. [Seaborn](http://seaborn.pydata.org/)
# 3. [Bokeh](http://bokeh.pydata.org/en/latest/)
#
# However, Pandas have a **.plot** namespace, with various chart types available **(line, hist, scatter, etc.)**.
#
# We will focus excelusively on  the high-level plotting availabel within pandas and seaborn.

# %% [markdown]
# ## 6.1 Pandas' builtin-plotting

# %% [markdown]
# Plot Formatting

# %% [markdown]
# #### Line plot

# %%
# %matplotlib inline

# %%
cities.latitude.plot()

# %% [markdown]
# #### Plot Scatter plot between latitude and temperature

# %%
cities.plot.scatter(x='temperature', y='latitude', c='#E88C0C', s=55)

# %% [markdown]
# #### Histograms¶

# %%
cities.temperature.hist(grid=False )

# %% [markdown]
# ### Boxplots
# A different way of visualizing the distribution of data is the boxplot, which is a display of common quantiles; these are typically the quartiles and the lower and upper 5 percent values.

# %%
cities.boxplot(column='temperature', grid=False,  return_type=None);

# %% [markdown]
# You can think of the box plot as viewing the distribution from above. The white circles are "outlier" points that occur outside the extreme quantiles.

# %% [markdown]
# ## References
#
# * [Jupyter Notebooks for the Python Data Science Handbook](https://github.com/jakevdp/PythonDataScienceHandbook)
# * [Pandas & Seaborn - A guide to handle & visualize data elegantly](https://tryolabs.com/blog/2017/03/16/pandas-seaborn-a-guide-to-handle-visualize-data-elegantly/)
